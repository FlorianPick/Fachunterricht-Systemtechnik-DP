# %% [markdown]
# # Lambda-Funktion (lambda-Operator, anonyme Funktion)
# (im Begleitbuch ab Seite 171)

# %% [markdown]
# Die einen lieben ihn, die anderen hassen ihn und viele fürchten ihn, den Lambda-Operator. Als Multiparadigmensprache unterstützt Python auch die funktionale Programmierung. Lambda-Funktionen kommen aus der funktionalen Programmierung. Mit Hilfe des lambda-Operators können anonyme Funktionen, d.h. Funktionen ohne Namen erzeugt werden. Sie haben eine beliebe Anzahl von Parametern, führen einen Ausdruck aus und liefern den Wert dieses Ausdrucks als Rückgabewert zurück.
#
# Anonyme Funktionen sind insbesondere bei der Anwendung der map-, filter- und reduce-Funktionen von großem Vorteil.
#
# Allgemeiner Aufbau einer Lambda-Funktion:
# **lambda** *Argumentenliste : Ausdruck*
# Die Argumentenliste besteht aus einer durch Kommata getrennten Liste von Argumenten und der Ausdruck ist ein Ausdruck der diese Argumente benutzt.
# Beispiel:

# %%
mathe1 = lambda x, y, z : x * y + z
print(type(mathe1))
mathe1(3, 5, 7)

# %%
mathe1(1,2,3)

# %%
def mathe1(a, b, c):
    return a * b + c
print(type(mathe1))

# %%
mathe1(3,5,7)

# %% [markdown]
# Bei einer Vielzahl von Aufrufen wird die lambda-Funktion deutlich Laufzeiteffizienter
# als eine herkömmliche Funktion, insbesondere auch bei zunehmender Anzahl von
# Parametern.

# %%
# lambda ohne Argument
sagHallo = lambda:print("Hallo Welt!")
sagHallo()

# %%
# lambda mit Argument, Verdoppelung
findeDopplung = lambda x: print("Das Doppelte: ", x * 2)
findeDopplung(10)

# %%
# lambda mit mehreren Argumenten, Summe
summe = lambda x, y, z: print("Summe: ", x + y + z)
summe(10,20,30)

# %%
# lambda direkt (5,3)
a = 5
b = 3
result = (lambda x1, x2: x1 + x2)(5,3)
#result = (lambda x1, x2: x1 + x2)(a,b)
# f = (lambda x1, x2: x1 + x2)
# for i in range(0,5):
#     result = f(i,b)
#     print(result)
print(result, type(result))

# %% [markdown]
# ## Lambda-Funktion mit if-else
# **x = lambda \<Argumente\>: \<Wert1\> if \<Bedingung1\> else \<Wert2\>**
# ## Lambda funktion mit verschachtelter if-else-Bedingung
# **y = lambda \<Argumente\>: \<Wert1\> if \<Bedingung1\> else (\<Wert2\> if \<Bedingung2\> else \<Wert3\>)**

# %%
# lambda Funktion mit if-else Bedingung
l1 = lambda x: x**2 if x <=5 else x+10
z = 5
print(l1(z))          # Berechnung mit lambda
############
if z <= 5:            # Herkömmlich
    print(z ** 2)
else:
    print(z + 10)

# %%
for i in range(0,8):
    print(l1(i))

# %%
# Lambda Funktion mit verschachtelter if-else-Bedingung
l2 = lambda y: y+10 if y%2 == 0 else (y*2 if y<5 else y*3)
print(f'\tj\tlambda l1\tlambda l2')
for j in range(11):
    print(f'{j:9}\t{l1(j):9}\t{l2(j):9}')

# %%
# Je nach Modus passende Konvertierungs-Lambda-Funktion zurückgeben
def converter(mode):
    if mode.upper() == 'C':
        aus = 'temp: temp / 5 * 9 + 32'
        return eval(f'lambda {aus}') # lambda temp: temp / 9 * 9 + 32
    else:
        return lambda temp: (temp - 32) / 9 * 5

# Modus abfragen und entsprechende Funktion abholen
mode = input("(C)elsius in Fahrenheit oder (F)ahrenheit in Celsius? ")
convert = converter(mode)   # Convert Funktion bestimmen
#print(convert, type(convert))
st = (lambda m:'Celsius' if m.upper() == 'C' else 'Fahrenheit')(mode)
st1 = (lambda m:'Fahrenheit' if m.upper() == 'C' else 'Celsius')(mode)
# Hauptschleife
while True:
#    temp = input(f"Temperatur in °{(lambda m:'Celsius' if m.upper() == 'C' else 'Fahrenheit')(mode)} eingeben: (Q/q für Ende)? ")    
    temp = input(f"Temperatur in °{st} eingeben: (Q/q oder ENTER für Ende)? ")    
    if temp.upper() in 'Q ':
#    if temp.upper() == 'Q':
        print('Programm ENDE')
        break
    print(f'Temperatur in °{st1} = {convert(float(temp))}')  # z.B: "lambda temp: temp / 5 * 9 + 32 (25)"

# %%
# Hier die Variablen st und st1 in der Funktion "converter" setzen und dem
# Hauptprogramm (Main) zur Verfügung stellen (*.upper() == 'C' wird mehrfach verwendet!)
########################################################################################

# %%
Funktionen eval() und exec()
x = 1
print(eval('x+1'))
print(x+1)
# cmd = 'x=99'
# exec(cmd)
# print(x-9)
# x = 1
# cmd = 'y = x + 99'
# exec(cmd)
# print(y)

# %% [markdown]
# # map() Funktion
#
#
# Quelle: https://www.digitalocean.com/community/tutorials/how-to-use-the-python-map-function-de
#
# Wir können die integrierte Python-Funktion map() verwenden, um für jedes Element in einer Iterablen (wie einer Liste oder einem Wörterbuch) eine Funktion anzuwenden und einen neuen Iterator zum Abrufen der Ergebnisse zurückgeben. map() gibt ein map-Objekt (einen Iterator) zurück, das wir in anderen Teilen unseres Programms nutzen können. Außerdem können wir das map-Objekt an die Funktion list() oder einen anderen Sequenztyp übergeben, um eine Iterable zu erstellen.
#
# Die Syntax für die Funktion map() lautet folgendermaßen:
#
# **map(function, iterable, [iterable 2, iterable 3, ...])**
#
# ## Verwenden einer Lambda-Funktion
#
# **map(lambda item: item[] expression, iterable)**

# %%
numbers = [10, 15, 21, 33, 42, 55]

# %%
# map-Objekte sind nur bis zum 1. Zugriff verfügbar
mapped_numbers = map(lambda x : x * 2 + 3, numbers)
#mapped_numbers = list(map(lambda x : x * 2 + 3, numbers))
print(type(mapped_numbers))
print(mapped_numbers)
list1 = list(mapped_numbers)
#print(list1)
#print(list(mapped_numbers), list1)
for i in list1:
#for i in mapped_numbers:
    print(i)
#print(list(mapped_numbers))        # Daten sind gelöscht !!
print(list1)

# %%
# Ergebnis direkt in eine Liste speichern zur späteren Verwendung
mapped_numbers = map(lambda x : x * 2 + 3, numbers)
liste = list(mapped_numbers)        # Ergebnis in Liste speichern --> mapped_numbers ist danach leer!!
#liste = list(map(lambda x : x * 2 + 3, numbers))    # Alternativ
for i in liste:
    print(i)
print(liste)

# %% [markdown]
# Hier deklarieren wir in unserer Liste ein Element als x. Dann fügen wir unseren Ausdruck hinzu. Wir übergeben unsere Liste mit Zahlen als Iterable für map().
#
# Um die Ergebnisse davon sofort zu erhalten, drucken wir eine Liste des map-Objekts aus:

# %%
mapped_numbers = map(lambda x : x * 2 + 3, numbers)
print(mapped_numbers)
x = list(mapped_numbers)
print(x)
print(mapped_numbers)
print(list(mapped_numbers))

# %% [markdown]
# Wir haben list() verwendet, damit das map-Objekt als Liste zurückgegeben wird und nicht als schlechter menschenlesbares Objekt wie: \<map object at 0x7fc250003a58\>. Das map-Objekt ist ein Iterator über unsere Ergebnisse; daher können wir mit for eine Schleife darüber legen oder list() verwenden, um es in eine Liste umzuwandeln. Wir tun dies hier, da es eine gute Möglichkeit zur Prüfung der Ergebnisse darstellt.
#
# **Achtung:** nach List() oder *for in* Itteration ist das ursprüngliche Objekt leer!

# %%
list1 = [1, 2, 3, 4, 5]
list2 = list(map(lambda x: x + 1, list1))
print(list2)

# %%
# map direkt
even_numbers = map(lambda x: x * 2, list1)       # Liste direkt
#even_numbers = map(lambda x: x * 2, [1,2,3,4])  # direkte Eingabe
#even_numbers = map(lambda x: x * 2, 'ABCD')     # direkte Eingabe
list(even_numbers)

# %%
# Sortieren einer Liste
my_list = [(3, 1, 5), (1, 2, 1), (11, -3, 0), (5, 10, 9)]
my_list.sort(key=lambda x: x[0]) # sortieren nach [0] oder [1] ...
print(my_list)

# %% [markdown]
# ## Verwenden einer integrierten Funktion mit mehreren Iterablen
#
# Genauso wie bei lambda-Funktionen oder unseren selbst definierten Funktionen können wir integrierte Python-Funktionen mit map() verwenden. Um eine Funktion mit mehreren Iterablen anzuwenden, übergeben wir nach dem ersten einen weiteren Iterablennamen. Verwenden Sie beispielsweise die Funktion pow(), die in zwei Zahlen nimmt, um die Potenz der Basisnummer für den bereitgestellten Exponenten zu finden.
#
# Hier sehen wir unsere Listen mit Integerzahlen, die wir mit pow() verwenden möchten:

# %%
help(pow)

# %%
base_numbers = [2, 4, 6, 8, 10]
powers = [1, 2, 3, 4, 5]

# %%
numbers_powers = map(pow, base_numbers, powers)
print(type(numbers_powers))
print(numbers_powers)
list_powers = list(numbers_powers)
print(list_powers)

# %% [markdown]
# map() wendet die Funktion pow() in jeder Liste auf das gleiche Element an, um die Potenz anzugeben. Daher werden unsere Ergebnisse 2\**1, 4\**2, 6\**3 usw. anzeigen:
#
# Wenn wir map() eine Iterable zur Verfügung stellen würden, die länger als die andere ist, würde map() die Berechnung stoppen, sobald das Ende der kürzesten Iterable erreicht ist. Im folgenden Programm ergänzen wir base_numbers um drei zusätzliche Zahlen:

# %%
base_numbers = [2, 4, 6, 8, 10, 12, 14, 16]
powers = [1, 2, 3, 4, 5]


numbers_powers = list(map(pow, base_numbers, powers))

print(numbers_powers)

# %% [markdown]
# Wir haben die Funktion map() mit einer **integrierten Python-Funktion** verwendet und gesehen, dass sie mehrere Iterablen handhaben kann. Außerdem haben wir überprüft, ob map() weitere Iterablen verarbeitet, bis das Ende der Iterablen mit den wenigsten Elementen erreicht wurde. Es wird keine Fehlermeldung ausgegeben!

# %% [markdown]
# # filter() Funktion
# Quelle: https://www.digitalocean.com/community/tutorials/how-to-use-the-python-filter-function-de
#
# Die in Python integrierte filter()-Funktion kann dazu dienen, aus einem vorhandenen iterable (wie einer Liste oder einem Wörterbuch) einen neuen iterator zu erstellen, der Elemente mithilfe einer von uns bereitgestellten Funktion effizient filtern kann. Ein iterable ist ein Python-Objekt, bei dem „iterated over“ möglich ist, d. h. Elemente werden in einer Reihenfolge zurückgegeben, die wir in einer for-Schleife verwenden können.
#
# Die grundlegende Syntax für die Funktion filter() lautet:
#
# **filter(function, iterable)**

# %%
# finde die geraden Nummern, x%2
my_list = [1,2,3,4,5,6,7,8,9]
even_numbers = filter(lambda x: x % 2 == 0, my_list)
print(type(even_numbers), even_numbers)
list(even_numbers)

# %%
ev_num =[]
for i in my_list:
    if i % 2 == 0:
        ev_num.append(i)
print(ev_num)

# %%
creature_names = ['Sammy', 'Ashley', 'Jo', 'Olly', 'Jackie', 'Charlie']

# %% [markdown]
# Mit einer Liste wie dieser können wir eine lambda-Funktion mit einem Ausdruck integrieren, gegen den wir die einzelnen Elemente aus der Liste bewerten möchten:

# %%
f = filter(lambda x: x[0].lower() in 'aeiou', creature_names)
print(type(f))
print(f)

# %% [markdown]
# Wenn wir das Ergebnis als Liste haben wollen muss die list() Funktion verwendet werden.

# %%
liste = list(f)
print(liste)

# %% [markdown]
# Alles in einer Codezeile!

# %%
print(list(filter(lambda x: x[0].lower() in 'aeiou', creature_names)))

# %% [markdown]
# Hier deklarieren wir einen Punkt in unserer Liste als x. Dann legen wir unseren Ausdruck so fest, dass er auf das erste Zeichen der jeweiligen Zeichenfolge (oder Zeichen „zero“) zugreift, also x[0]. Durch Kleinschreibung aller Namen wird sichergestellt, dass Buchstaben mit der Zeichenfolge in unserem Ausdruck (aeiou) abgeglichen werden.
#
# Abschließend übergeben wir das iterable creature_names. Wie im vorherigen Abschnitt wenden wir list() auf das Ergebnis an, um eine Liste aus den iterator filter()-Ergebnissen zu erstellen.

# %%
# Das gleiche Ergebnis aber mit einer Funktion!
creature_names = ['Sammy', 'Ashley', 'Jo', 'Olly', 'Jackie', 'Charlie']

def names_vowels(x):
    return x[0].lower() in 'aeiou'

filtered_names = filter(names_vowels, creature_names)

print(list(filtered_names))

# %% [markdown]
# ## Verwenden von **None** mit filter()
# Wir können **None** als erstes Argument an filter() übergeben, damit der zurückgegebene iterator alle Werte ausgibt, die Python nicht als „falsy“ erachtet. Im Allgemeinen betrachtet Python alles mit einer Länge von 0 (wie eine leere Liste oder eine leere Zeichenfolge) und alles, was 0 numerisch entspricht, als „false“, daher die Verwendung des Begriffs „falsy“.
#
# Im folgenden Fall möchten wir unsere Liste so filtern, dass nur die Tanknummern unseres Aquariums angezeigt werden:

# %%
aquarium_tanks = [11, False, 18, 21, "", 12, 34.3, 0, [], {}, (), 3+1j, True, -3]
print(aquarium_tanks)

# %% [markdown]
# Wir verwenden die Funktion filter() mit None und übergeben die Liste aquarium_tanks als unser iterable. Da wir None als erstes Argument übergeben haben, prüfen wir, ob die Elemente in unserer Liste als false angesehen werden.

# %%
filtered_tanks = filter(None , aquarium_tanks)
print(type(filtered_tanks))
print(filtered_tanks)
print(list(filtered_tanks))        # list() um Inhalt von filtered_tanks

# %%
filtered_tanks = filter(lambda x: (type(x) in [int, float, complex]) and x != 0, aquarium_tanks)
print(type(filtered_tanks))
print(filtered_tanks)
print(list(filtered_tanks))        # list() um Inhalt von filtered_tanks

# %% [markdown]
# Bei None haben wir filter() verwendet, um Elemente aus unserer Liste schnell zu entfernen, die als falsy betrachtet wurden.
#
# Dies kann bei der Bereinigung von eingehenden Daten eine nützliche und schnelle Funktion sein, um Daten schnell auszusortieren.

# %% [markdown]
# **Anmerkung:**
#
# Wenn wir list() nicht verwenden und filtered_tanks drucken, erhalten wir ein Filterobjekt, das etwa so aussieht: \<Filter object at 0x7fafd5903240\>. Das Filterobjekt ist ein **iterable**, sodass wir ein **loop over mit for** vornehmen können; alternativ können wir **list()** verwenden, um es in eine Liste umzuwandeln. Dies tun wir hier, da es eine gute Möglichkeit ist, die Ergebnisse zu prüfen.

# %% [markdown]
# # Reduce()
#
# Die Reduce-Funktion zur Addition von Objekten
#
# Bei der Reduce-Funktion wird die angegebene Funktion, in unserem Fall eine Lambda-Funktion, auf die ersten beiden Werte der Liste angewendet und nun das Ergebnis wieder mit dem nächsten Listenpunkt zusammengearbeitet.

# %%
from functools import reduce

lst = [100,200,300,400]

print(reduce(lambda x,y: x+y,lst))
print(sum(lst))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
reduce(lambda x,y: x*y , [10,8,6]) # (10 * 8) * 6

# %%
reduce(lambda x,y: x**y , [2,4,3]) # (2 ** 4) ** 3

# %%
reduce(lambda x,y: x%y , [103,7,6]) # (103 % 7) % 6
