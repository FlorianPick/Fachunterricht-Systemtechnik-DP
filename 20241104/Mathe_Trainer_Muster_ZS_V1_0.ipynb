# %% [markdown]
# # Mathe Trainer
#
# Schreiben Sie ein Python-Programm, um einem Schüler zu helfen, Mathematik zu üben.
# Das Programm sollte den Schüler zuerst fragen, wie viele Übungen er machen möchte.
#
# Fangen Sie die Eingabe einer zu hohen Zahl (z.B. >100) oder eines Strings ab. und fordern eine neue Eingabe an.
# Sollte eine Fliesskommazahl eingegeben werden wird deren Integer-Wert benutzt.
#
# Dann soll das Programm zwei Zufallszahlen zwischen 1 und 10 generieren und zufällig einen Operator + oder - oder * auswählen und eine Übung generieren.
#
# Dann liest es die Antwort des Schülers in der Eingabe und teilt mit, ob die Antwort richtig war. Wenn die Antwort falsch war, sollte die richtige Antwort angezeigt werden.
#
# Auch hier die Eingabe auf eine gültige Zahl hin überprüfen und gegebenenfalls eine neue Eingabe anfordern.
#
# ```python
# >>> Wie viele Übungsläufe möchten Sie machen?  2
# >>> 2 * 7 = ?
# 14
# >>> "Ja, das ist richtig!"
# >>> 3 * 10 = ?
# 21
# >>> "Leider falsch. Die korrekte Antwort lautet: 30"
# ```
#
# **(30 Punkte)**

# %%
int(input('Eingabe: '))

# %%
while True:
    try:
        inp = int(input('Eingabe : '))
    except ValueError as error:
        print(error)
        print('Falsche Eingabe bitte eine Zahl eingeben')
    else:
        if inp <= 100:
            break
        else:
            print('Anzahl der Versuche darf maximal 100 betragen!')
print(inp)

# %%
'1.3.4'.count('.')

# %%
eingabe = input()
if eingabe.strip('-').replace('.','').isnumeric():  # '-' Vorzeichen und '.' für isdigit Prüfung entfernen
    eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
print(eingabe, type(eingabe))

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, isnumeric(), random: randint, choice
from random import randint      #
from random import choice
score = 0    # Variable für richtige Lösungen
while True:                     # Schleife wird auf jeden Fall gestartet/betreten
    loop = input('Wieviele Übungen wollen Sie machen? ')     # Variable loop ist ein String!
    if loop.isdigit():          # Wenn loop eine Zahl ist (isdigit)      
        loop = int(loop)        # wandle loop in eine Integer Zahl um
        if 0 < loop <= 100:     # wenn loop grösser 0 und kleiner gleich als 100 ist
            break               # verlasse die while Schleife
        else:                   # zu hoher Wert für Anzahl Übungen
            print('Falsche Eingabe: zu hohe Anzahl!(>100) oder 0 Übungen!')
            #continue            # erneute Eingabe
    else:                       # es wurde keine Zahl eingegeben
        print('Falsche Eingabe: Nur ganze Zahlen zwischen 1 und 100!')
for i in range(0, loop):
    # Aufgabe zusammenstellen Dezimal
    a = randint(1, 10)                # 1. Zufallszahl
    b = randint(1, 10)                # 2. Zufallszahl
    o = choice('+-*')                 # Operator
    aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
    #aufgabe = str(a) + ' ' + o + ' ' + str(b)  # Aufgabe als String mit Leerzeichen
    #aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
    #aufgabe = str(a) + o + str(b)              # Aufgabe als String ohne Leerzeichen
    #print(aufgabe,type(aufgabe))
    ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
    # Ergebnis der Berechnung abfragen
    while True:
        eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ? ').replace(',', '.') # Komma wird durch Punkt ersetzt
        if eingabe.strip('-').replace('.','').isdigit() and eingabe.count('.') <=1:  # '-' Vorzeichen und '.' für isdigit Prüfung entfernen
                                                                                     # keine 2 oder mehr Trennzeichen (, oder .)  
            eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
            break                          # while-Schleife verlassen --> gültige Zahl eingegeben
        else:                              # es wurde keine Zahl eingegeben
            print('Keine Zahl eingegeben: Erneut versuchen!')
    # Auswertung
    if eingabe == ergebnis:
        print(f'Die Lösung {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
        score += 1  # entspricht score = score + 1
    else:
        print(f'Die Lösung {aufgabe} = {eingabe} ist falsch! ')
        print(f'Das korrekte Ergebnis ist {ergebnis}.')
# Berechnung und Ausgabe des Ergebnisses
l = int(score / loop * 100)
if l >= 92:
    n = 1
elif 91 >= l >= 81:
    n = 2
elif 80 >= l >= 67:
    n = 3
elif 66 >= l >= 50:
    n = 4
elif 49 >= l >= 30:
    n = 5
else:
    n = 6
print(53*'#')
print(f'Ihre Note nach IHK-Notenschlüssel ist: {n} ({l:3} Punkte)')
print(53*'#')

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, isnumeric(), random: randint, choice
from random import randint      #
from random import choice
score = 0    # Variable für richtige Lösungen
while True:                     # Schleife wird auf jeden Fall gestartet/betreten
    loop = input('Wieviele Übungen wollen Sie machen? ')     # Variable loop ist ein String!
    if loop.isdigit():          # Wenn loop eine Zahl ist (isdigit)      
        loop = int(loop)        # wandle loop in eine Integer Zahl um
        if 0 < loop <= 100:     # wenn loop grösser 0 und kleiner gleich als 100 ist
            break               # verlasse die while Schleife
        else:                   # zu hoher Wert für Anzahl Übungen
            print('Falsche Eingabe: zu hohe Anzahl!(>100) oder 0 Übungen!')
#            continue            # erneute Eingabe
    else:                       # es wurde keine Zahl eingegeben
        print('Falsche Eingabe: Nur ganze Zahlen zwischen 1 und 100!')
for i in range(0, loop):
    # Aufgabe zusammenstellen Dezimal
    a = randint(1, 10)                # 1. Zufallszahl
    b = randint(1, 10)                # 2. Zufallszahl
    o = choice('+-*')                 # Operator
    aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
    #aufgabe = str(a) + ' ' + o + ' ' + str(b)  # Aufgabe als String mit Leerzeichen
    #aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
    #aufgabe = str(a) + o + str(b)              # Aufgabe als String ohne Leerzeichen
    #print(aufgabe,type(aufgabe))
    ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
    # Ergebnis der Berechnung abfragen
    while True:
        eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ? ').replace(',', '.')
        if eingabe.strip('-').replace('.','').isdigit() and eingabe.count('.') <=1:  # '-' Vorzeichen und '.' für isdigit Prüfung entfernen
            eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
            break                          # while-Schleife verlassen --> gültige Zahl eingegeben
        else:                              # es wurde keine Zahl eingegeben
            print('Keine Zahl eingegeben: Erneut versuchen!')
    # Auswertung
    if eingabe == ergebnis:
        print(f'Die Lösung {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
        score += 1  # entspricht score = score + 1
    else:
        print(f'Die Lösung {aufgabe} = {eingabe} ist falsch! ')
        print(f'Das korrekte Ergebnis ist {ergebnis}.')
# Berechnung und Ausgabe des Ergebnisses
l = int(score / loop * 100)
if l >= 92:
    n = 1
elif 91 >= l >= 81:
    n = 2
elif 80 >= l >= 67:
    n = 3
elif 66 >= l >= 50:
    n = 4
elif 49 >= l >= 30:
    n = 5
else:
    n = 6
print(53*'#')
print(f'Ihre Note nach IHK-Notenschlüssel ist: {n} ({l:3} Punkte)')
print(53*'#')

# %%
eingabe = '-20.2'
print(eingabe.strip('-').replace('.','').isdigit())
eingabe = eingabe.strip('-')        # entfernt das '-' Zeichen
print(eingabe,eingabe.isdigit())
eingabe = eingabe.replace('.','')
print(eingabe,eingabe.isdigit())

# %% [markdown]
# ### Optional
#
# Erweitern Sie Ihre Lösung so, dass neben arithmetischen Operatoren auch boolesche Operatoren unterstützt werden. Der Benutzer sollte nur mit „Wahr“ oder „Falsch“ antworten, ansonsten muss die Eingabe wiederholt werden. ( w und f als Auswahl ist auch OK)
#
# **(5 Punkte zusätzlich)**

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, bin(), random: randint, choice
from random import randint      
from random import choice
import sys
score = 0                       # Variable für richtige Lösungen
print(53*'_')
print('''
1  Dezimalrechnung +, - und *
2  Boolesche Operatoren ==, >=, <=, !=, <, >\n
q  Programm verlassen
''')
print(53*'_')
while True:
    auswahl = input('Welches Aufgabengebiet wollen Sie üben? (1, 2, q für verlassen) ' )
    if auswahl.lower() in ['1', '2', 'q']:
        break
    else:
        print('Falsche Auswahl! 1, 2, oder q auswählen.')
if auswahl.lower() == 'q':
    print('Programm verlassen.')
else:
    while True:
        loop = input('Wieviele Übungen wollen Sie machen? ')
        if loop.isdigit():
            loop = int(loop)
            if 0 < loop <= 100:     # wenn loop grösser 0 und kleiner gleich als 100 ist
                break
            else:                   # zu hoher Wert für Anzahl Übungen
                print('Falsche Eingabe: zu hohe Anzahl!(>100) oder 0 Übungen!')
#                continue            # erneute Eingabe
        else:                       # es wurde keine Zahl eingegeben
            print('Falsche Eingabe: Nur ganze Zahlen zwischen 1 und 100!')
    if auswahl == '1':              # Dezimale Berechnungen
        for i in range(0, loop):
            # Aufgabe zusammenstellen
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice('+-*')                 # Operator
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
            #aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
            #aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
            #aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            #print(aufgabe,type(aufgabe))
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ### Ergebnis der Berechnung abfragen ###
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ? ').replace(',', '.')
                if eingabe.strip('-').replace('.','').isdigit() and eingabe.count('.') <=1:  # '-' Vorzeichen für isdigit Prüfung entfernen
                    eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('Keine Zahl eingegeben: Erneut versuchen!')
            ### Auswertung ###
            if eingabe == ergebnis:
                print(f'Die Lösung {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung {aufgabe} = {eingabe} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis}.')
    elif auswahl == '2':              # Boolesche Operatoren
        for i in range(0, loop):
            ### Aufgabe zusammenstellen ###
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice(('==', '>=', '<=', '!=', '<', '>'))  # Operator als Liste
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
    #        aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
    #        aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
    #        aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ### Ergebnis der Berechnung abfragen ###
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ?\n"w" für Wahr oder "f" für Falsch eingeben. ')
#                if eingabe.lower() == 'w' or eingabe.lower() == 't':
                if eingabe.lower() in 'wt':
                    eingabe = True
                    break
                elif eingabe.lower() == 'f':
                    eingabe = False
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('Falsche Eingabe: "w" für Wahr oder "f" für Falsch eingeben.')
            # Auswertung
            if eingabe == ergebnis:
                print(f'Die Lösung {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung {aufgabe} = {eingabe} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis}.')
    # Berechnung und Ausgabe des Ergebnisses
    l = int(score / loop * 100)
    if l >= 92:
        n = 1
    elif 91 >= l >= 81:
        n = 2
    elif 80 >= l >= 67:
        n = 3
    elif 66 >= l >= 50:
        n = 4
    elif 49 >= l >= 30:
        n = 5
    else:
        n = 6
    print(53*'#')
    print(f'Ihre Note nach IHK-Notenschlüssel ist: {n} ({l:3} Punkte)')
    print(53*'#')
print('Programmende, Vielen Dank')

# %% [markdown]
# ### Optional zum kniffeln
#
# Erweitern Sie Ihre Lösung so, dass bitweise Operatoren unterstützt werden.
# Die Eingabe und Ausgabe sollte die binäre Form (010011) unterstützen.Der Binärwert sollte maximal 8 Stellen lang sein. Bei Fehler muss die Eingabe wiederholt werden oder mit 'quit' abgebrochen werden.
#
# **(15 Punkte zusätzlich)**

# %%
f'{25:>08b}'

# %%
print(type(int(input('Frage: '),2)))

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, bin(), random: randint, choice
from random import randint      
from random import choice
import sys
score = 0                       # Variable für richtige Lösungen
print(53*'_')
print('''
1  Dezimalrechnung +, - und *
2  Boolesche Operatoren ==, >=, <=, !=, <, >
3  Bitweise Operatoren and (&), or (|), xor (\u005E)\n 
q  Programm verlassen
''')
print(53*'_')
while True:
    auswahl = input('Welches Aufgabengebiet wollen Sie üben? (1, 2, 3, q für verlassen) ' )
    if auswahl.lower() in ['1', '2', '3', 'q']:
        break
    else:
        print('Falsche Auswahl! 1, 2, 3 oder q auswählen.')
if auswahl.lower() == 'q':
    print('Programm verlassen.')
else:
    while True:
        loop = input('Wieviele Übungen wollen Sie machen? ')
        if loop.isdigit():
            loop = int(loop)
            if 0 < loop <= 100:     # wenn loop grösser 0 und kleiner gleich als 100 ist
                break
            else:                   # zu hoher Wert für Anzahl Übungen
                print('Falsche Eingabe: zu hohe Anzahl!(>100) oder 0 Übungen!')
#                continue            # erneute Eingabe
        else:                       # es wurde keine Zahl eingegeben
            print('Falsche Eingabe: Nur ganze Zahlen zwischen 1 und 100!')
    if auswahl == '1':              # Dezimale Berechnungen
        for i in range(0, loop):
            # Aufgabe zusammenstellen
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice('+-*')                 # Operator
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
            #aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
            #aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
            #aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            #print(aufgabe,type(aufgabe))
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ########################################
            ### Ergebnis der Berechnung abfragen ###
            ########################################
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ? ').replace(',', '.')
                if eingabe.strip('-').replace('.','').isdigit() and eingabe.count('.') <=1:  # '-' Vorzeichen für isdigit Prüfung entfernen
                    eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('F E H L E R !: Keine Zahl eingegeben: Erneut versuchen!')
            ##################
            ### Auswertung ###
            ##################
            if eingabe == ergebnis:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis}.')
    elif auswahl == '2':              # Boolesche Operatoren
        for i in range(0, loop):
            ### Aufgabe zusammenstellen ###
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice(['==', '>=', '<=', '!=', '<', '>'])  # Operator
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
    #        aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
    #        aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
    #        aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ### Ergebnis der Berechnung abfragen ###
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ?\n"w" für Wahr oder "f" für Falsch eingeben. ')
                if eingabe.lower() == 'w' or eingabe.lower() == 't':
                    eingabe = True
                    break
                elif eingabe.lower() == 'f':
                    eingabe = False
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('Falsche Eingabe: "w" für Wahr oder "f" für Falsch eingeben.')
            # Auswertung
            if eingabe == ergebnis:
                print(f'Die Lösung {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung {aufgabe} = {eingabe} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis}.')
    elif auswahl == '3':              # Boolesche Operatoren
        for i in range(0, loop):
            ### Aufgabe zusammenstellen ###
            a = randint(0, 255)           # 1. Zufallszahl binär
            b = randint(0, 255)           # 2. Zufallszahl binär
            o = choice(['&', '|', '^'])  # Operator
            # , '<<', '>>'
            aufgabe = f'{a:0>8b} {o} {b:0>8b}' # Aufgabe als String mit Leerzeichen (binär formatiert!)
            ergebnis = eval(f'{a}{o}{b}')      # Ergebnis der Aufgabe als Integer
            #print(ergebnis, a, b)
            while True:
                eingabe = int(input(f'Wie lautet die Lösung für:\n {a:0>8b}\n  {o}\n {b:0>8b} ?\n'),2)
                break
            if eingabe == ergebnis:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe:0>8b} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe:0>8b} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis:>8b}.')
            
    # Berechnung und Ausgabe des Ergebnisses
    l = int(score / loop * 100)
    if l >= 92:
        n = 1
    elif 91 >= l >= 81:
        n = 2
    elif 80 >= l >= 67:
        n = 3
    elif 66 >= l >= 50:
        n = 4
    elif 49 >= l >= 30:
        n = 5
    else:
        n = 6
    print(53*'#')
    print(f'Ihre Note nach IHK-Notenschlüssel ist: {n} ({l:3} Punkte)')
    print(53*'#')
print('Programmende, Vielen Dank')

# %% [markdown]
# ### Mit Funktionen

# %%
# Hier Ihren Programmcode eintragen
# Hinweise:eval(), while, bin(), random: randint, choice
from random import randint      
from random import choice
import sys
score = 0                       # Variable für richtige Lösungen

def check(s):      # Prüfen ob die Eingabe korrekt ist 
    ##################
    ### Auswertung ###
    ##################
    if eingabe == ergebnis:
        print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe} ist korrekt! Glückwunsch')
        return s + 1
    else:
        print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe} ist falsch! ')
        print(f'Das korrekte Ergebnis ist {ergebnis}.')
        return s
   
    

print(53*'_')
print('''
1  Dezimalrechnung +, - und *
2  Boolesche Operatoren ==, >=, <=, !=, <, >
3  Bitweise Operatoren and (&), or (|), xor (\u005E)\n 
q  Programm verlassen
''')
print(53*'_')
while True:
    auswahl = input('Welches Aufgabengebiet wollen Sie üben? (1, 2, 3, q für verlassen) ' )
    if auswahl.lower() in ['1', '2', '3', 'q']:
        break
    else:
        print('Falsche Auswahl! 1, 2, 3 oder q auswählen.')
if auswahl.lower() == 'q':
    print('Programm verlassen.')
else:
    while True:
        loop = input('Wieviele Übungen wollen Sie machen? ')
        if loop.isdigit():
            loop = int(loop)
            if 0 < loop <= 100:     # wenn loop grösser 0 und kleiner gleich als 100 ist
                break
            else:                   # zu hoher Wert für Anzahl Übungen
                print('Falsche Eingabe: zu hohe Anzahl!(>100) oder 0 Übungen!')
#                continue            # erneute Eingabe
        else:                       # es wurde keine Zahl eingegeben
            print('Falsche Eingabe: Nur ganze Zahlen zwischen 1 und 100!')
    if auswahl == '1':              # Dezimale Berechnungen
        for i in range(0, loop):
            # Aufgabe zusammenstellen
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice('+-*')                 # Operator
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
            #aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
            #aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
            #aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            #print(aufgabe,type(aufgabe))
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ########################################
            ### Ergebnis der Berechnung abfragen ###
            ########################################
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ? ').replace(',', '.')
                if eingabe.strip('-').replace('.','').isdigit() and eingabe.count('.') <=1:  # '-' Vorzeichen für isdigit Prüfung entfernen
                    eingabe = int(float(eingabe))  # Eingabestring (mit Vorzeichen) in Integer umwandeln
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('F E H L E R !: Keine Zahl eingegeben: Erneut versuchen!')
            ##################
            ### Auswertung ###
            ##################
            score = check(score)      # Prüfe Eingabe
    elif auswahl == '2':              # Boolesche Operatoren
        for i in range(0, loop):
            ### Aufgabe zusammenstellen ###
            a = str(randint(1, 10))           # 1. Zufallszahl
            b = str(randint(1, 10))           # 2. Zufallszahl
            o = choice(['==', '>=', '<=', '!=', '<', '>'])  # Operator
            aufgabe = f'{a} {o} {b}'          # Aufgabe als String mit Leerzeichen (! f'')
    #        aufgabe = a + ' ' + o + ' ' + b  # Aufgabe als String mit Leerzeichen
    #        aufgabe = f'{a}{o}{b}'           # Aufgabe als String ohne Leerzeichen
    #        aufgabe = a + o + b              # Aufgabe als String ohne Leerzeichen
            ergebnis = eval(aufgabe)          # Ergebnis der Aufgabe als Integer
            ### Ergebnis der Berechnung abfragen ###
            while True:
                eingabe = input(f'Wie lautet die Lösung für: {aufgabe} ?\n"w" für Wahr oder "f" für Falsch eingeben. ')
                if eingabe.lower() == 'w' or eingabe.lower() == 't':
                    eingabe = True
                    break
                elif eingabe.lower() == 'f':
                    eingabe = False
                    break                   # while-Schleife verlassen --> gültige Zahl eingegeben
                else:                       # es wurde keine Zahl eingegeben
                    print('Falsche Eingabe: "w" für Wahr oder "f" für Falsch eingeben.')
            ##################
            ### Auswertung ###
            ##################
            score = check(score)      # Prüfe Eingabe
    elif auswahl == '3':              # Boolesche Operatoren
        for i in range(0, loop):
            ### Aufgabe zusammenstellen ###
            a = randint(0, 255)           # 1. Zufallszahl binär
            b = randint(0, 255)           # 2. Zufallszahl binär
            o = choice(['&', '|', '^'])  # Operator
            # , '<<', '>>'
            aufgabe = f'{a:0>8b} {o} {b:0>8b}' # Aufgabe als String mit Leerzeichen (binär formatiert!)
            ergebnis = eval(f'{a}{o}{b}')      # Ergebnis der Aufgabe als Integer
            #print(ergebnis, a, b)
            while True:
                eingabe = input(f'Wie lautet die Lösung für:\n {a:0>8b}\n  {o}\n {b:0>8b} ?\n')
                if eingabe == '': eingabe = '0'
                eingabe = int(eingabe,2)
                break
            ##################
            ### Auswertung ###
            ##################
            if eingabe == ergebnis:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe:0>8b} ist korrekt! Glückwunsch')
                score += 1
            else:
                print(f'Die Lösung von Aufgabe {i+1}: {aufgabe} = {eingabe:0>8b} ist falsch! ')
                print(f'Das korrekte Ergebnis ist {ergebnis:0>8b}.')
            
    # Berechnung und Ausgabe des Ergebnisses
    l = int(score / loop * 100)
    if l >= 92:
        n = 1
    elif 91 >= l >= 81:
        n = 2
    elif 80 >= l >= 67:
        n = 3
    elif 66 >= l >= 50:
        n = 4
    elif 49 >= l >= 30:
        n = 5
    else:
        n = 6
    print(53*'#')
    print(f'Ihre Note nach IHK-Notenschlüssel ist: {n} ({l:3} Punkte)')
    print(53*'#')
print('Programmende, Vielen Dank')
